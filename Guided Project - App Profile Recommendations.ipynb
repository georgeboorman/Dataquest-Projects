# %% [markdown]
# # Guided Project: Profitable App Profiles for the App Store and Google Play Markets
# The following project will analyse Google Play Store and Apple Store datasets with the aim of identifying characteristics correlated with app profitability.
# The analysis will be used to inform a business case for the creation of an app with a profile designed to maximise profitability through high user engagement and associated advertising revenue streams.

# %%
from csv import reader
#Apple Store#
opened_file = open(C:\Users\boormang\Desktop\Dataquest\Files\AppleStore.csv)
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios = ios[1:]

#Google Play Store#
opened_file = (C:\Users\boormang\Desktop\Dataquest\Files\googleplaystore.csv)
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android = android[1:]
# Out:
#   File "<ipython-input-6-02ff66f2324d>", line 3
#     opened_file = open(C:\Users\boormang\Desktop\Dataquest\Files\AppleStore.csv)
#                         ^
# SyntaxError: invalid syntax
